# %%
import pandas as  pd

# %%
path="C:\RAE\Printers\Printer_IP's_new.xlsx"
df=pd.read_excel(path)

# %%
df
# Out:
#                Printer      Location                     New printer  \
# 0        Ricoh C3004_3             3            Minolta Bizhub C300i
# 1         xerox 3635_7             7                  sharp mx-3050v
# 2        Ricoh C3004_2             2                   Ricoh C3004_2
# 3                oki_3             3               oki_3 (γώγουλου?)
# 4           oki_6 B412             3                      oki_6 B412
# 5        Ricoh C3004_4             4            Minolta Bizhub C300i
# 6        Ricoh C3004_5             5  Xerox Altalink C8130 5th floor
# 7    hp 6040_6 (x-3os)             6                  sharp mx-3050v
# 8               4520_4             3                  sharp mx-3050v
# 9               5200_6             6                          5200_6
# 10                 NaN             7           oki mc363 (vice pres)
# 11           hp cp1025             2                     hp cp1025nw
# 12                 NaN             7                oki mc363 (pres)
# ...
